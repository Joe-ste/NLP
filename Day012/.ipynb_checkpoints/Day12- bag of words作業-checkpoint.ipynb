# %% [markdown]
# ## 作業目標：搭建一個bag of words模型

# %% [markdown]
# ---

# %%
import pandas as pd
import nltk
nltk.download('punkt')
import numpy as np
dataset=pd.read_csv('Restaurant_Reviews.tsv',delimiter='\t',quoting=3)
corpus=dataset['Review'].values
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\JoeZhong\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.

# %% [markdown]
# ### 從文本中取出所有單字

# %%
whole_words = []
for sentence in corpus:
    tokenized_sentence = nltk.word_tokenize(sentence)
    for word in tokenized_sentence:
        whole_words.append(word)

# %% [markdown]
# ### 移除重複單字

# %%
whole_words = set(whole_words)
print('共有{}個單字'.format(len(whole_words)))
# Out:
# 共有2351個單字

# %% [markdown]
# ### 建立字典使每一個單字有對應數值

# %%
word_index = {}
index_word = {}
n = 0
for word in whole_words:
    """自行填入"""
    word_index[word] = n
    index_word[n] = word
    n += 1

# %%
word_index
# Out:
# {'Up': 0,
#  '7.85': 1,
#  'serivce': 2,
#  'portion': 3,
#  'traditional': 4,
#  'Mirage': 5,
#  'presentation': 6,
#  'two': 7,
#  'dirty-': 8,
#  'other': 9,
#  'quantity': 10,
#  'reading': 11,
#  'mein': 12,
#  'funny': 13,
#  'last': 14,
#  'vibe': 15,
#  'management': 16,
#  'cavier': 17,
#  'smelled': 18,
#  'mushrooms': 19,
#  'atmosphere.1': 20,
#  'freaking': 21,
#  'surprise': 22,
#  'grandmother': 23,
#  'fabulous': 24,
#  'app': 25,
#  'IN': 26,
#  'item': 27,
#  'an': 28,
#  'chipolte': 29,
#  'price': 30,
#  'ladies': 31,
#  'largely': 32,
#  'above': 33,
#  'worries': 34,
#  'tenders': 35,
#  'elegantly': 36,
#  'guys': 37,
#  'neighborhood': 38,
#  'so': 39,
#  'Lox': 40,
#  'may': 41,
#  'stay': 42,
#  'gristle': 43,
#  'unprofessional': 44,
#  'gotten': 45,
#  'Plus': 46,
#  'considering': 47,
#  'hair': 48,
#  'slices': 49,
#  'website': 50,
#  'Went': 51,
#  'Panna': 52,
#  'five': 53,
#  'patio': 54,
#  'started': 55,
#  'space': 56,
#  'Outstanding': 57,
#  'arrives': 58,
#  'etc': 59,
#  'selection': 60,
#  'weekend': 61,
#  'buying': 62,
#  'works': 63,
#  'ever': 64,
#  'acknowledged': 65,
#  'personally': 66,
#  'huevos': 67,
#  'before': 68,
#  'Once': 69,
#  'plus': 70,
#  'veal': 71,
#  'Perhaps': 72,
#  'cool': 73,
#  'compliments': 74,
#  'airport': 75,
#  'stop': 76,
#  'Egg': 77,
#  'muffin': 78,
#  'bodes': 79,
#  'here': 80,
#  'together': 81,
#  'ribeye': 82,
#  'AND': 83,
#  'highlights': 84,
#  'cold': 85,
#  'Maybe': 86,
#  'disappointed': 87,
#  'Have': 88,
#  'non-customer': 89,
#  'over': 90,
#  'caterpillar': 91,
#  'certainly': 92,
#  'cooked': 93,
#  'charge': 94,
#  'can': 95,
#  'home': 96,
#  'Really': 97,
#  'Wonderful': 98,
#  'colder': 99,
#  'awkwardly': 100,
#  'hip': 101,
#  'capers': 102,
#  'over-hip': 103,
#  'famous': 104,
#  'duck': 105,
#  'cashew': 106,
#  'favorite': 107,
#  'customize': 108,
#  'stood': 109,
#  'At': 110,
#  'neat': 111,
#  'Join': 112,
#  'warmer': 113,
#  'street': 114,
#  'exceeding': 115,
#  'crab': 116,
#  'pats': 117,
#  'Toast': 118,
#  'gyro': 119,
#  'sample': 120,
#  'bartenders': 121,
#  'inflate': 122,
#  'bloddy': 123,
#  'choux': 124,
#  'baklava': 125,
#  'make': 126,
#  'lunch': 127,
#  'FLAVOR': 128,
#  'light': 129,
#  'revisiting': 130,
#  'again': 131,
#  'professional': 132,
#  'Bad': 133,
#  'seen': 134,
#  'Yama': 135,
#  'things': 136,
#  'starving': 137,
#  'worst': 138,
#  'venturing': 139,
#  'delicioso': 140,
#  'Soups': 141,
#  'best': 142,
#  'occasions': 143,
#  'Last': 144,
#  'mess': 145,
#  'tuna': 146,
#  'order': 147,
#  'each': 148,
#  'Steiners': 149,
#  'vodka': 150,
#  '15': 151,
#  'Ryan': 152,
#  'today': 153,
#  'cuisine': 154,
#  'decent': 155,
#  'touch': 156,
#  'small': 157,
#  'crêpe': 158,
#  'says': 159,
#  'dine': 160,
#  'day': 161,
#  'amount': 162,
#  '-My': 163,
#  'letdown': 164,
#  'bakery': 165,
#  'single': 166,
#  's': 167,
#  'offers': 168,
#  'dont': 169,
#  'bits': 170,
#  'Google': 171,
#  'You': 172,
#  'suck': 173,
#  'Camelback': 174,
#  'killer': 175,
#  'welcome': 176,
#  'LOVED': 177,
#  'prompt': 178,
#  'flair': 179,
#  'poop': 180,
#  'daughter': 181,
#  'speedy': 182,
#  'still': 183,
#  'APPETIZERS': 184,
#  'descriptions': 185,
#  'waste': 186,
#  'came': 187,
#  'Generous': 188,
#  'as': 189,
#  'burgers': 190,
#  'section': 191,
#  'least': 192,
#  'fried': 193,
#  'strawberry': 194,
#  'charcoal': 195,
#  'reasons': 196,
#  'Yelpers': 197,
#  'covers': 198,
#  'greens': 199,
#  'frozen': 200,
#  'wave': 201,
#  'Always': 202,
#  'Mandalay': 203,
#  'sushi': 204,
#  'douchey': 205,
#  'ravoli': 206,
#  'cannoli': 207,
#  'although': 208,
#  'provides': 209,
#  'block': 210,
#  'smoothies': 211,
#  'by': 212,
#  'hereas': 213,
#  'great': 214,
#  'accident': 215,
#  '``': 216,
#  'guacamole': 217,
#  'texture': 218,
#  'Ninja': 219,
#  'bar': 220,
#  'ignored': 221,
#  'NOT': 222,
#  'absolutely': 223,
#  'Unfortunately': 224,
#  'My': 225,
#  '12': 226,
#  'usual': 227,
#  'sliced': 228,
#  'definately': 229,
#  'playing': 230,
#  'sore': 231,
#  'receives': 232,
#  'Would': 233,
#  'disapppointment': 234,
#  'dripping': 235,
#  'mayo': 236,
#  'awful': 237,
#  'case': 238,
#  'closed': 239,
#  'six': 240,
#  'from': 241,
#  'fluffy': 242,
#  'deal': 243,
#  'parties': 244,
#  'peach': 245,
#  'pastry': 246,
#  'seasonal': 247,
#  'return': 248,
#  'otherwise': 249,
#  'An': 250,
#  'much': 251,
#  'white': 252,
#  'believe': 253,
#  'mom': 254,
#  'fan': 255,
#  "'s": 256,
#  'inch': 257,
#  'time': 258,
#  'paper': 259,
#  'High-quality': 260,
#  'rubber': 261,
#  'miss': 262,
#  'wanted': 263,
#  'beateous': 264,
#  'drunk': 265,
#  'rinse': 266,
#  'breaks': 267,
#  'helpful': 268,
#  'interesting': 269,
#  'underwhelming': 270,
#  'rushed': 271,
#  'WHAT': 272,
#  'cash': 273,
#  'Cape': 274,
#  'satisfied': 275,
#  'Weird': 276,
#  'Place': 277,
#  'tastings': 278,
#  'Jeff': 279,
#  'pan': 280,
#  'lost': 281,
#  'edible': 282,
#  'Friend': 283,
#  'Hut': 284,
#  'Mmmm': 285,
#  'Must': 286,
#  'point': 287,
#  'Caesar': 288,
#  'could': 289,
#  'legs': 290,
#  'after': 291,
#  'undercooked': 292,
#  'sides': 293,
#  'Highly': 294,
#  'operation': 295,
#  'looked': 296,
#  'soup': 297,
#  'suggest': 298,
#  'salsa': 299,
#  'hottest': 300,
#  'unique': 301,
#  'these': 302,
#  'flavored': 303,
#  'maybe': 304,
#  'chow': 305,
#  'classics': 306,
#  'informative': 307,
#  'belly': 308,
#  'Third': 309,
#  '11.99': 310,
#  'treated': 311,
#  'disgraceful': 312,
#  'prefer': 313,
#  'until': 314,
#  'felt': 315,
#  'Favorite': 316,
#  'nigiri': 317,
#  'anyone': 318,
#  'while': 319,
#  'human': 320,
#  'fun': 321,
#  'Nice': 322,
#  'Ample': 323,
#  'lived': 324,
#  'pay': 325,
#  'redeeming': 326,
#  'man': 327,
#  'Dylan': 328,
#  'Sat': 329,
#  'nay': 330,
#  'appealing': 331,
#  'better': 332,
#  'lighter': 333,
#  'Bisque': 334,
#  'powdered': 335,
#  'disappoint': 336,
#  'treat': 337,
#  'daily': 338,
#  'quickly': 339,
#  'mouth': 340,
#  'pace': 341,
#  'attack': 342,
#  'disgrace': 343,
#  'arriving': 344,
#  'possible': 345,
#  'low': 346,
#  'grease': 347,
#  'Soggy': 348,
#  'someone': 349,
#  'plate': 350,
#  'Excalibur': 351,
#  'ethic': 352,
#  'Caballero': 353,
#  'large': 354,
#  'lot': 355,
#  'passed': 356,
#  'quite': 357,
#  'modern': 358,
#  'banana': 359,
#  'apart': 360,
#  'ingredients': 361,
#  'lady': 362,
#  'cocktails': 363,
#  'down': 364,
#  'Han': 365,
#  'arrived': 366,
#  'promptly': 367,
#  'tartar': 368,
#  'bruschetta': 369,
#  'complete': 370,
#  'during': 371,
#  'disgusted': 372,
#  'pneumatic': 373,
#  'how': 374,
#  'coconut': 375,
#  'portions': 376,
#  'location': 377,
#  'word': 378,
#  'judge': 379,
#  'wish': 380,
#  'topic': 381,
#  'nasty': 382,
#  'Nargile': 383,
#  'served': 384,
#  'However': 385,
#  'bank': 386,
#  'creamy': 387,
#  'Wienerschnitzel': 388,
#  'Best': 389,
#  'Breeze': 390,
#  '23': 391,
#  'Wo': 392,
#  'bloodiest': 393,
#  'andddd': 394,
#  'dead': 395,
#  'non-fancy': 396,
#  'cost': 397,
#  'glance': 398,
#  'monster': 399,
#  'pancake': 400,
#  'judging': 401,
#  'different': 402,
#  'alone': 403,
#  'teeth': 404,
#  'marrow': 405,
#  'tiramisu': 406,
#  'Sun': 407,
#  'guest': 408,
#  'requested': 409,
#  'Insults': 410,
#  'added': 411,
#  'Chicken': 412,
#  'thats': 413,
#  'hate': 414,
#  'parents': 415,
#  'industry': 416,
#  'half': 417,
#  'talk': 418,
#  'middle': 419,
#  'rich': 420,
#  'tongue': 421,
#  'Heimer': 422,
#  'nicest': 423,
#  'words': 424,
#  ':': 425,
#  'kid': 426,
#  'UNREAL': 427,
#  'fantastic': 428,
#  'Seat': 429,
#  'busy': 430,
#  'anything': 431,
#  '1': 432,
#  'Baba': 433,
#  'succulent': 434,
#  'night': 435,
#  'BARGAIN': 436,
#  'clean': 437,
#  'oil': 438,
#  'vomited': 439,
#  'Owner': 440,
#  'generous': 441,
#  'pissd': 442,
#  'bone': 443,
#  'manager': 444,
#  'Which': 445,
#  'feeling': 446,
#  'shops': 447,
#  'sub': 448,
#  'curry': 449,
#  'perfectly': 450,
#  'NASTY': 451,
#  'really': 452,
#  "'": 453,
#  'with': 454,
#  'pecan': 455,
#  'beauty': 456,
#  'insanely': 457,
#  'HOUR': 458,
#  'margaritas': 459,
#  'totally': 460,
#  'yellowtail': 461,
#  'at': 462,
#  'convenient': 463,
#  'TOLD': 464,
#  'Tigerlilly': 465,
#  'IT': 466,
#  'pancakes': 467,
#  'Overall': 468,
#  'The': 469,
#  'poured': 470,
#  'station': 471,
#  'boys': 472,
#  'black': 473,
#  'hopes': 474,
#  'They': 475,
#  'HAPPENED': 476,
#  'recently': 477,
#  'Of': 478,
#  'cart': 479,
#  'bamboo': 480,
#  'eaten': 481,
#  'bug': 482,
#  'worst/annoying': 483,
#  'Elk': 484,
#  'running': 485,
#  'chefs': 486,
#  'devine': 487,
#  'helped': 488,
#  'drinks': 489,
#  'when': 490,
#  '$': 491,
#  'events': 492,
#  'Back': 493,
#  'Phenomenal': 494,
#  'rowdy': 495,
#  'heard': 496,
#  'chewy': 497,
#  'close': 498,
#  'Before': 499,
#  'Strip': 500,
#  'seemed': 501,
#  'crawfish': 502,
#  'opposed': 503,
#  'a': 504,
#  'handmade': 505,
#  'server': 506,
#  'tepid': 507,
#  'very': 508,
#  '-': 509,
#  'highlighted': 510,
#  'them': 511,
#  'meal': 512,
#  'trip': 513,
#  'mary': 514,
#  'goat': 515,
#  'long': 516,
#  'English': 517,
#  'tolerance': 518,
#  'said': 519,
#  'am': 520,
#  'everything': 521,
#  'expanded': 522,
#  'highlight': 523,
#  'fair': 524,
#  'swung': 525,
#  'if': 526,
#  'caring': 527,
#  'mediocre': 528,
#  'ignore': 529,
#  'cramming': 530,
#  'hard': 531,
#  'hamburger': 532,
#  'binge': 533,
#  'FLY': 534,
#  'SHOULD': 535,
#  'new': 536,
#  'checked': 537,
#  'constructed': 538,
#  'This': 539,
#  'Took': 540,
#  'As': 541,
#  'full': 542,
#  'area/': 543,
#  'kids': 544,
#  'Baseball': 545,
#  'pretty': 546,
#  'Update': 547,
#  'Much': 548,
#  'deliciously': 549,
#  'On': 550,
#  'puréed': 551,
#  'hole': 552,
#  'steakhouse': 553,
#  'back': 554,
#  'AVOID': 555,
#  'know': 556,
#  'outstanding': 557,
#  'Hunan': 558,
#  'prepare': 559,
#  'bought': 560,
#  'Albondigas': 561,
#  'out': 562,
#  'Great': 563,
#  'joint': 564,
#  'low-key': 565,
#  'doing': 566,
#  'drive': 567,
#  'style': 568,
#  'lacking': 569,
#  'mac': 570,
#  'club': 571,
#  'class': 572,
#  'Vegetarian': 573,
#  'AGAIN': 574,
#  'Reasonably': 575,
#  'plastic': 576,
#  'replenished': 577,
#  'Grill': 578,
#  'falafels': 579,
#  'longer': 580,
#  'dude': 581,
#  'delivery': 582,
#  'suffers': 583,
#  'Spend': 584,
#  'Italian': 585,
#  'joke': 586,
#  'Despite': 587,
#  'chip': 588,
#  'reason': 589,
#  'surprised': 590,
#  'eyes': 591,
#  'inside': 592,
#  'sandwich': 593,
#  'spicy': 594,
#  'this': 595,
#  'circumstances': 596,
#  'fella': 597,
#  'accordingly': 598,
#  'find': 599,
#  'breakfast/lunch': 600,
#  'ago': 601,
#  'something': 602,
#  'kitchen': 603,
#  'Host': 604,
#  'yellow': 605,
#  'tops': 606,
#  'front': 607,
#  'talking': 608,
#  'drag': 609,
#  'spaghetti': 610,
#  'inviting': 611,
#  'covered': 612,
#  'touched': 613,
#  'vegetables': 614,
#  'us': 615,
#  'Ians': 616,
#  'Each': 617,
#  'Tried': 618,
#  'terrific': 619,
#  'pub': 620,
#  'outshining': 621,
#  'Over': 622,
#  'fondue': 623,
#  'efficient': 624,
#  'Rick': 625,
#  'forty': 626,
#  'indicate': 627,
#  'imaginative': 628,
#  'Hiro': 629,
#  'have': 630,
#  'enough': 631,
#  'Stars': 632,
#  'quick': 633,
#  'ball': 634,
#  'OF': 635,
#  'Waited': 636,
#  'guests': 637,
#  'indoor': 638,
#  'moist': 639,
#  'perpared': 640,
#  'readers': 641,
#  'To': 642,
#  'HANDS': 643,
#  'Nothing': 644,
#  'dollars': 645,
#  'impeccable': 646,
#  'going': 647,
#  'end': 648,
#  'Pita': 649,
#  'only': 650,
#  'discount': 651,
#  'wants': 652,
#  'Sprouts': 653,
#  'pack': 654,
#  "''": 655,
#  'needs': 656,
#  'liked': 657,
#  'food': 658,
#  'degree': 659,
#  'want': 660,
#  'ensued': 661,
#  'That': 662,
#  'ache': 663,
#  'far': 664,
#  'postinos': 665,
#  'menus': 666,
#  'people': 667,
#  'healthy': 668,
#  'bellies': 669,
#  'beat': 670,
#  'wash': 671,
#  'grab': 672,
#  'roasted': 673,
#  'restaurant': 674,
#  'help': 675,
#  'chef': 676,
#  'Hands': 677,
#  'real': 678,
#  'understand': 679,
#  'authentic': 680,
#  'venture': 681,
#  'Eew': 682,
#  'wasted': 683,
#  'like': 684,
#  'fav': 685,
#  'leather': 686,
#  'spends': 687,
#  'haunt': 688,
#  'disbelief': 689,
#  'stomach': 690,
#  'cause': 691,
#  'finally': 692,
#  'airline': 693,
#  'gone': 694,
#  'greatest': 695,
#  'MANY': 696,
#  'Cod': 697,
#  'sick': 698,
#  'Waiter': 699,
#  'friends': 700,
#  'experience': 701,
#  'Cartel': 702,
#  'particular': 703,
#  'eyed': 704,
#  'mood': 705,
#  'apologize': 706,
#  'Café': 707,
#  'papers': 708,
#  'BLAND': 709,
#  'choose': 710,
#  'crowds': 711,
#  'thought': 712,
#  'GREAT': 713,
#  'nut': 714,
#  'give': 715,
#  'employees': 716,
#  'never': 717,
#  'once': 718,
#  'Im': 719,
#  'fries': 720,
#  'itself': 721,
#  'madhouse': 722,
#  'definitely': 723,
#  'appetizers': 724,
#  'OK': 725,
#  '1979': 726,
#  'soggy': 727,
#  'And': 728,
#  'play': 729,
#  'spotty': 730,
#  'imagination': 731,
#  'Vegas': 732,
#  'loving': 733,
#  'were': 734,
#  'beans': 735,
#  'iced': 736,
#  'right': 737,
#  'accomodate': 738,
#  'pulled': 739,
#  'worker': 740,
#  'grossed': 741,
#  'watered': 742,
#  'ohhh': 743,
#  'Then': 744,
#  'handed': 745,
#  'but': 746,
#  'Frenchman': 747,
#  'hardly': 748,
#  'elsewhere': 749,
#  'worse': 750,
#  'soundtrack': 751,
#  'WILL': 752,
#  'Anyway': 753,
#  'Same': 754,
#  'tough': 755,
#  'ate': 756,
#  'beef': 757,
#  'Dog': 758,
#  'beer': 759,
#  'disappointment': 760,
#  'stretch': 761,
#  'styrofoam': 762,
#  'dinners': 763,
#  'decorated': 764,
#  "'ve": 765,
#  'tender': 766,
#  'hand': 767,
#  'hungry': 768,
#  'Francisco': 769,
#  'Furthermore': 770,
#  'whatsoever': 771,
#  'dough': 772,
#  'set': 773,
#  'round': 774,
#  'spots': 775,
#  'thing': 776,
#  '20': 777,
#  'AYCE': 778,
#  'hours': 779,
#  'Server': 780,
#  'old': 781,
#  'watched': 782,
#  'winner': 783,
#  'kind': 784,
#  'courteous': 785,
#  'tummy': 786,
#  'regularly': 787,
#  'some': 788,
#  'leftover': 789,
#  'bird': 790,
#  'actually': 791,
#  'Omelets': 792,
#  'memory': 793,
#  'part': 794,
#  'it': 795,
#  'Khao': 796,
#  'restaurants': 797,
#  'wonderful': 798,
#  'gratuity': 799,
#  '90': 800,
#  'combination': 801,
#  'Pretty': 802,
#  'first': 803,
#  'bunch': 804,
#  'salty': 805,
#  'done': 806,
#  'cranberry': 807,
#  '%': 808,
#  'Kind': 809,
#  'duo': 810,
#  'any': 811,
#  'ice': 812,
#  'businesses': 813,
#  'Stopped': 814,
#  'tried': 815,
#  'tea': 816,
#  'Awesome': 817,
#  'tasty': 818,
#  'summer': 819,
#  'sewer': 820,
#  'wedges': 821,
#  'boy': 822,
#  'working/eating': 823,
#  'guess': 824,
#  'others': 825,
#  'disgust': 826,
#  'WAY': 827,
#  'obviously': 828,
#  'die': 829,
#  'flop': 830,
#  'pricey': 831,
#  'bad': 832,
#  'equally': 833,
#  'Gringos': 834,
#  'number': 835,
#  'husband': 836,
#  '6': 837,
#  'behind': 838,
#  'Sooooo': 839,
#  'stinks': 840,
#  'mind': 841,
#  'music': 842,
#  'ALL': 843,
#  'Otto': 844,
#  'silently': 845,
#  'exactly': 846,
#  'means': 847,
#  '3': 848,
#  'tomato': 849,
#  'brought': 850,
#  'setting': 851,
#  'sad': 852,
#  'downside': 853,
#  'quit': 854,
#  'sub-par': 855,
#  "'ll": 856,
#  'Sushi': 857,
#  'coffee': 858,
#  'between': 859,
#  'found': 860,
#  'We': 861,
#  'wings': 862,
#  'hardest': 863,
#  'promise': 864,
#  'Seafood': 865,
#  'late': 866,
#  'wo': 867,
#  'to-go': 868,
#  'Now': 869,
#  'mid': 870,
#  'containers': 871,
#  'shirt': 872,
#  'NYC': 873,
#  'establishment': 874,
#  'Avoid': 875,
#  'staff': 876,
#  'Our': 877,
#  'fish': 878,
#  'cover': 879,
#  'version': 880,
#  'everyone': 881,
#  'writing': 882,
#  '.....': 883,
#  'milk': 884,
#  'entire': 885,
#  'profiterole': 886,
#  'shoe': 887,
#  'expensive': 888,
#  'in': 889,
#  'pizzas': 890,
#  "'m": 891,
#  'MANAGEMENT': 892,
#  'water': 893,
#  'North': 894,
#  'loves': 895,
#  'correction': 896,
#  'tailored': 897,
#  'fact': 898,
#  'DELICIOUS': 899,
#  'buffets': 900,
#  'Also': 901,
#  'spring': 902,
#  'whether': 903,
#  'absolutley': 904,
#  'How': 905,
#  'When': 906,
#  'driving': 907,
#  'atmosphere': 908,
#  'Greek': 909,
#  'workers': 910,
#  'pita': 911,
#  'All': 912,
#  'instead': 913,
#  'Crust': 914,
#  'Bouchon': 915,
#  'myself': 916,
#  'beautifully': 917,
#  'drinking': 918,
#  'FREEZING': 919,
#  'cheese': 920,
#  'nude': 921,
#  'grow': 922,
#  'decor': 923,
#  'sever': 924,
#  'consider': 925,
#  'somewhat': 926,
#  'free': 927,
#  'Macarons': 928,
#  'more': 929,
#  'expect': 930,
#  'minutes': 931,
#  'finger': 932,
#  'Thumbs': 933,
#  'weekly': 934,
#  'probably': 935,
#  'effort': 936,
#  'fellow': 937,
#  'appalling': 938,
#  'Customer': 939,
#  'OMG': 940,
#  'sandwiches': 941,
#  'bartender': 942,
#  'Madison': 943,
#  'book': 944,
#  'horrible': 945,
#  'changing': 946,
#  'sunglasses': 947,
#  'pricing': 948,
#  'desserts': 949,
#  'somehow': 950,
#  'room': 951,
#  'venue': 952,
#  'recommend': 953,
#  'awkward': 954,
#  'Based': 955,
#  'recommendation': 956,
#  'Not': 957,
#  'flavors': 958,
#  'especially': 959,
#  'few': 960,
#  'little': 961,
#  'extraordinary': 962,
#  'will': 963,
#  'assure': 964,
#  'Crystals': 965,
#  'reservation': 966,
#  'showed': 967,
#  'ten': 968,
#  'LEGIT': 969,
#  'places': 970,
#  'crumby': 971,
#  'go': 972,
#  'drawing': 973,
#  'ESTABLISHMENT': 974,
#  'GO': 975,
#  'stale': 976,
#  'Mushroom': 977,
#  'whole': 978,
#  'ca': 979,
#  'refused': 980,
#  'original': 981,
#  'Area': 982,
#  'turn': 983,
#  'rating': 984,
#  '10': 985,
#  'Good': 986,
#  'TV': 987,
#  'First': 988,
#  'sangria': 989,
#  'lovely': 990,
#  'fairly': 991,
#  'THAT': 992,
#  'he': 993,
#  'bus': 994,
#  'atrocious': 995,
#  'Salad': 996,
#  'market': 997,
#  'hands-down': 998,
#  'care': 999,
#  ...}

# %%
index_word
# Out:
# {0: 'Up',
#  1: '7.85',
#  2: 'serivce',
#  3: 'portion',
#  4: 'traditional',
#  5: 'Mirage',
#  6: 'presentation',
#  7: 'two',
#  8: 'dirty-',
#  9: 'other',
#  10: 'quantity',
#  11: 'reading',
#  12: 'mein',
#  13: 'funny',
#  14: 'last',
#  15: 'vibe',
#  16: 'management',
#  17: 'cavier',
#  18: 'smelled',
#  19: 'mushrooms',
#  20: 'atmosphere.1',
#  21: 'freaking',
#  22: 'surprise',
#  23: 'grandmother',
#  24: 'fabulous',
#  25: 'app',
#  26: 'IN',
#  27: 'item',
#  28: 'an',
#  29: 'chipolte',
#  30: 'price',
#  31: 'ladies',
#  32: 'largely',
#  33: 'above',
#  34: 'worries',
#  35: 'tenders',
#  36: 'elegantly',
#  37: 'guys',
#  38: 'neighborhood',
#  39: 'so',
#  40: 'Lox',
#  41: 'may',
#  42: 'stay',
#  43: 'gristle',
#  44: 'unprofessional',
#  45: 'gotten',
#  46: 'Plus',
#  47: 'considering',
#  48: 'hair',
#  49: 'slices',
#  50: 'website',
#  51: 'Went',
#  52: 'Panna',
#  53: 'five',
#  54: 'patio',
#  55: 'started',
#  56: 'space',
#  57: 'Outstanding',
#  58: 'arrives',
#  59: 'etc',
#  60: 'selection',
#  61: 'weekend',
#  62: 'buying',
#  63: 'works',
#  64: 'ever',
#  65: 'acknowledged',
#  66: 'personally',
#  67: 'huevos',
#  68: 'before',
#  69: 'Once',
#  70: 'plus',
#  71: 'veal',
#  72: 'Perhaps',
#  73: 'cool',
#  74: 'compliments',
#  75: 'airport',
#  76: 'stop',
#  77: 'Egg',
#  78: 'muffin',
#  79: 'bodes',
#  80: 'here',
#  81: 'together',
#  82: 'ribeye',
#  83: 'AND',
#  84: 'highlights',
#  85: 'cold',
#  86: 'Maybe',
#  87: 'disappointed',
#  88: 'Have',
#  89: 'non-customer',
#  90: 'over',
#  91: 'caterpillar',
#  92: 'certainly',
#  93: 'cooked',
#  94: 'charge',
#  95: 'can',
#  96: 'home',
#  97: 'Really',
#  98: 'Wonderful',
#  99: 'colder',
#  100: 'awkwardly',
#  101: 'hip',
#  102: 'capers',
#  103: 'over-hip',
#  104: 'famous',
#  105: 'duck',
#  106: 'cashew',
#  107: 'favorite',
#  108: 'customize',
#  109: 'stood',
#  110: 'At',
#  111: 'neat',
#  112: 'Join',
#  113: 'warmer',
#  114: 'street',
#  115: 'exceeding',
#  116: 'crab',
#  117: 'pats',
#  118: 'Toast',
#  119: 'gyro',
#  120: 'sample',
#  121: 'bartenders',
#  122: 'inflate',
#  123: 'bloddy',
#  124: 'choux',
#  125: 'baklava',
#  126: 'make',
#  127: 'lunch',
#  128: 'FLAVOR',
#  129: 'light',
#  130: 'revisiting',
#  131: 'again',
#  132: 'professional',
#  133: 'Bad',
#  134: 'seen',
#  135: 'Yama',
#  136: 'things',
#  137: 'starving',
#  138: 'worst',
#  139: 'venturing',
#  140: 'delicioso',
#  141: 'Soups',
#  142: 'best',
#  143: 'occasions',
#  144: 'Last',
#  145: 'mess',
#  146: 'tuna',
#  147: 'order',
#  148: 'each',
#  149: 'Steiners',
#  150: 'vodka',
#  151: '15',
#  152: 'Ryan',
#  153: 'today',
#  154: 'cuisine',
#  155: 'decent',
#  156: 'touch',
#  157: 'small',
#  158: 'crêpe',
#  159: 'says',
#  160: 'dine',
#  161: 'day',
#  162: 'amount',
#  163: '-My',
#  164: 'letdown',
#  165: 'bakery',
#  166: 'single',
#  167: 's',
#  168: 'offers',
#  169: 'dont',
#  170: 'bits',
#  171: 'Google',
#  172: 'You',
#  173: 'suck',
#  174: 'Camelback',
#  175: 'killer',
#  176: 'welcome',
#  177: 'LOVED',
#  178: 'prompt',
#  179: 'flair',
#  180: 'poop',
#  181: 'daughter',
#  182: 'speedy',
#  183: 'still',
#  184: 'APPETIZERS',
#  185: 'descriptions',
#  186: 'waste',
#  187: 'came',
#  188: 'Generous',
#  189: 'as',
#  190: 'burgers',
#  191: 'section',
#  192: 'least',
#  193: 'fried',
#  194: 'strawberry',
#  195: 'charcoal',
#  196: 'reasons',
#  197: 'Yelpers',
#  198: 'covers',
#  199: 'greens',
#  200: 'frozen',
#  201: 'wave',
#  202: 'Always',
#  203: 'Mandalay',
#  204: 'sushi',
#  205: 'douchey',
#  206: 'ravoli',
#  207: 'cannoli',
#  208: 'although',
#  209: 'provides',
#  210: 'block',
#  211: 'smoothies',
#  212: 'by',
#  213: 'hereas',
#  214: 'great',
#  215: 'accident',
#  216: '``',
#  217: 'guacamole',
#  218: 'texture',
#  219: 'Ninja',
#  220: 'bar',
#  221: 'ignored',
#  222: 'NOT',
#  223: 'absolutely',
#  224: 'Unfortunately',
#  225: 'My',
#  226: '12',
#  227: 'usual',
#  228: 'sliced',
#  229: 'definately',
#  230: 'playing',
#  231: 'sore',
#  232: 'receives',
#  233: 'Would',
#  234: 'disapppointment',
#  235: 'dripping',
#  236: 'mayo',
#  237: 'awful',
#  238: 'case',
#  239: 'closed',
#  240: 'six',
#  241: 'from',
#  242: 'fluffy',
#  243: 'deal',
#  244: 'parties',
#  245: 'peach',
#  246: 'pastry',
#  247: 'seasonal',
#  248: 'return',
#  249: 'otherwise',
#  250: 'An',
#  251: 'much',
#  252: 'white',
#  253: 'believe',
#  254: 'mom',
#  255: 'fan',
#  256: "'s",
#  257: 'inch',
#  258: 'time',
#  259: 'paper',
#  260: 'High-quality',
#  261: 'rubber',
#  262: 'miss',
#  263: 'wanted',
#  264: 'beateous',
#  265: 'drunk',
#  266: 'rinse',
#  267: 'breaks',
#  268: 'helpful',
#  269: 'interesting',
#  270: 'underwhelming',
#  271: 'rushed',
#  272: 'WHAT',
#  273: 'cash',
#  274: 'Cape',
#  275: 'satisfied',
#  276: 'Weird',
#  277: 'Place',
#  278: 'tastings',
#  279: 'Jeff',
#  280: 'pan',
#  281: 'lost',
#  282: 'edible',
#  283: 'Friend',
#  284: 'Hut',
#  285: 'Mmmm',
#  286: 'Must',
#  287: 'point',
#  288: 'Caesar',
#  289: 'could',
#  290: 'legs',
#  291: 'after',
#  292: 'undercooked',
#  293: 'sides',
#  294: 'Highly',
#  295: 'operation',
#  296: 'looked',
#  297: 'soup',
#  298: 'suggest',
#  299: 'salsa',
#  300: 'hottest',
#  301: 'unique',
#  302: 'these',
#  303: 'flavored',
#  304: 'maybe',
#  305: 'chow',
#  306: 'classics',
#  307: 'informative',
#  308: 'belly',
#  309: 'Third',
#  310: '11.99',
#  311: 'treated',
#  312: 'disgraceful',
#  313: 'prefer',
#  314: 'until',
#  315: 'felt',
#  316: 'Favorite',
#  317: 'nigiri',
#  318: 'anyone',
#  319: 'while',
#  320: 'human',
#  321: 'fun',
#  322: 'Nice',
#  323: 'Ample',
#  324: 'lived',
#  325: 'pay',
#  326: 'redeeming',
#  327: 'man',
#  328: 'Dylan',
#  329: 'Sat',
#  330: 'nay',
#  331: 'appealing',
#  332: 'better',
#  333: 'lighter',
#  334: 'Bisque',
#  335: 'powdered',
#  336: 'disappoint',
#  337: 'treat',
#  338: 'daily',
#  339: 'quickly',
#  340: 'mouth',
#  341: 'pace',
#  342: 'attack',
#  343: 'disgrace',
#  344: 'arriving',
#  345: 'possible',
#  346: 'low',
#  347: 'grease',
#  348: 'Soggy',
#  349: 'someone',
#  350: 'plate',
#  351: 'Excalibur',
#  352: 'ethic',
#  353: 'Caballero',
#  354: 'large',
#  355: 'lot',
#  356: 'passed',
#  357: 'quite',
#  358: 'modern',
#  359: 'banana',
#  360: 'apart',
#  361: 'ingredients',
#  362: 'lady',
#  363: 'cocktails',
#  364: 'down',
#  365: 'Han',
#  366: 'arrived',
#  367: 'promptly',
#  368: 'tartar',
#  369: 'bruschetta',
#  370: 'complete',
#  371: 'during',
#  372: 'disgusted',
#  373: 'pneumatic',
#  374: 'how',
#  375: 'coconut',
#  376: 'portions',
#  377: 'location',
#  378: 'word',
#  379: 'judge',
#  380: 'wish',
#  381: 'topic',
#  382: 'nasty',
#  383: 'Nargile',
#  384: 'served',
#  385: 'However',
#  386: 'bank',
#  387: 'creamy',
#  388: 'Wienerschnitzel',
#  389: 'Best',
#  390: 'Breeze',
#  391: '23',
#  392: 'Wo',
#  393: 'bloodiest',
#  394: 'andddd',
#  395: 'dead',
#  396: 'non-fancy',
#  397: 'cost',
#  398: 'glance',
#  399: 'monster',
#  400: 'pancake',
#  401: 'judging',
#  402: 'different',
#  403: 'alone',
#  404: 'teeth',
#  405: 'marrow',
#  406: 'tiramisu',
#  407: 'Sun',
#  408: 'guest',
#  409: 'requested',
#  410: 'Insults',
#  411: 'added',
#  412: 'Chicken',
#  413: 'thats',
#  414: 'hate',
#  415: 'parents',
#  416: 'industry',
#  417: 'half',
#  418: 'talk',
#  419: 'middle',
#  420: 'rich',
#  421: 'tongue',
#  422: 'Heimer',
#  423: 'nicest',
#  424: 'words',
#  425: ':',
#  426: 'kid',
#  427: 'UNREAL',
#  428: 'fantastic',
#  429: 'Seat',
#  430: 'busy',
#  431: 'anything',
#  432: '1',
#  433: 'Baba',
#  434: 'succulent',
#  435: 'night',
#  436: 'BARGAIN',
#  437: 'clean',
#  438: 'oil',
#  439: 'vomited',
#  440: 'Owner',
#  441: 'generous',
#  442: 'pissd',
#  443: 'bone',
#  444: 'manager',
#  445: 'Which',
#  446: 'feeling',
#  447: 'shops',
#  448: 'sub',
#  449: 'curry',
#  450: 'perfectly',
#  451: 'NASTY',
#  452: 'really',
#  453: "'",
#  454: 'with',
#  455: 'pecan',
#  456: 'beauty',
#  457: 'insanely',
#  458: 'HOUR',
#  459: 'margaritas',
#  460: 'totally',
#  461: 'yellowtail',
#  462: 'at',
#  463: 'convenient',
#  464: 'TOLD',
#  465: 'Tigerlilly',
#  466: 'IT',
#  467: 'pancakes',
#  468: 'Overall',
#  469: 'The',
#  470: 'poured',
#  471: 'station',
#  472: 'boys',
#  473: 'black',
#  474: 'hopes',
#  475: 'They',
#  476: 'HAPPENED',
#  477: 'recently',
#  478: 'Of',
#  479: 'cart',
#  480: 'bamboo',
#  481: 'eaten',
#  482: 'bug',
#  483: 'worst/annoying',
#  484: 'Elk',
#  485: 'running',
#  486: 'chefs',
#  487: 'devine',
#  488: 'helped',
#  489: 'drinks',
#  490: 'when',
#  491: '$',
#  492: 'events',
#  493: 'Back',
#  494: 'Phenomenal',
#  495: 'rowdy',
#  496: 'heard',
#  497: 'chewy',
#  498: 'close',
#  499: 'Before',
#  500: 'Strip',
#  501: 'seemed',
#  502: 'crawfish',
#  503: 'opposed',
#  504: 'a',
#  505: 'handmade',
#  506: 'server',
#  507: 'tepid',
#  508: 'very',
#  509: '-',
#  510: 'highlighted',
#  511: 'them',
#  512: 'meal',
#  513: 'trip',
#  514: 'mary',
#  515: 'goat',
#  516: 'long',
#  517: 'English',
#  518: 'tolerance',
#  519: 'said',
#  520: 'am',
#  521: 'everything',
#  522: 'expanded',
#  523: 'highlight',
#  524: 'fair',
#  525: 'swung',
#  526: 'if',
#  527: 'caring',
#  528: 'mediocre',
#  529: 'ignore',
#  530: 'cramming',
#  531: 'hard',
#  532: 'hamburger',
#  533: 'binge',
#  534: 'FLY',
#  535: 'SHOULD',
#  536: 'new',
#  537: 'checked',
#  538: 'constructed',
#  539: 'This',
#  540: 'Took',
#  541: 'As',
#  542: 'full',
#  543: 'area/',
#  544: 'kids',
#  545: 'Baseball',
#  546: 'pretty',
#  547: 'Update',
#  548: 'Much',
#  549: 'deliciously',
#  550: 'On',
#  551: 'puréed',
#  552: 'hole',
#  553: 'steakhouse',
#  554: 'back',
#  555: 'AVOID',
#  556: 'know',
#  557: 'outstanding',
#  558: 'Hunan',
#  559: 'prepare',
#  560: 'bought',
#  561: 'Albondigas',
#  562: 'out',
#  563: 'Great',
#  564: 'joint',
#  565: 'low-key',
#  566: 'doing',
#  567: 'drive',
#  568: 'style',
#  569: 'lacking',
#  570: 'mac',
#  571: 'club',
#  572: 'class',
#  573: 'Vegetarian',
#  574: 'AGAIN',
#  575: 'Reasonably',
#  576: 'plastic',
#  577: 'replenished',
#  578: 'Grill',
#  579: 'falafels',
#  580: 'longer',
#  581: 'dude',
#  582: 'delivery',
#  583: 'suffers',
#  584: 'Spend',
#  585: 'Italian',
#  586: 'joke',
#  587: 'Despite',
#  588: 'chip',
#  589: 'reason',
#  590: 'surprised',
#  591: 'eyes',
#  592: 'inside',
#  593: 'sandwich',
#  594: 'spicy',
#  595: 'this',
#  596: 'circumstances',
#  597: 'fella',
#  598: 'accordingly',
#  599: 'find',
#  600: 'breakfast/lunch',
#  601: 'ago',
#  602: 'something',
#  603: 'kitchen',
#  604: 'Host',
#  605: 'yellow',
#  606: 'tops',
#  607: 'front',
#  608: 'talking',
#  609: 'drag',
#  610: 'spaghetti',
#  611: 'inviting',
#  612: 'covered',
#  613: 'touched',
#  614: 'vegetables',
#  615: 'us',
#  616: 'Ians',
#  617: 'Each',
#  618: 'Tried',
#  619: 'terrific',
#  620: 'pub',
#  621: 'outshining',
#  622: 'Over',
#  623: 'fondue',
#  624: 'efficient',
#  625: 'Rick',
#  626: 'forty',
#  627: 'indicate',
#  628: 'imaginative',
#  629: 'Hiro',
#  630: 'have',
#  631: 'enough',
#  632: 'Stars',
#  633: 'quick',
#  634: 'ball',
#  635: 'OF',
#  636: 'Waited',
#  637: 'guests',
#  638: 'indoor',
#  639: 'moist',
#  640: 'perpared',
#  641: 'readers',
#  642: 'To',
#  643: 'HANDS',
#  644: 'Nothing',
#  645: 'dollars',
#  646: 'impeccable',
#  647: 'going',
#  648: 'end',
#  649: 'Pita',
#  650: 'only',
#  651: 'discount',
#  652: 'wants',
#  653: 'Sprouts',
#  654: 'pack',
#  655: "''",
#  656: 'needs',
#  657: 'liked',
#  658: 'food',
#  659: 'degree',
#  660: 'want',
#  661: 'ensued',
#  662: 'That',
#  663: 'ache',
#  664: 'far',
#  665: 'postinos',
#  666: 'menus',
#  667: 'people',
#  668: 'healthy',
#  669: 'bellies',
#  670: 'beat',
#  671: 'wash',
#  672: 'grab',
#  673: 'roasted',
#  674: 'restaurant',
#  675: 'help',
#  676: 'chef',
#  677: 'Hands',
#  678: 'real',
#  679: 'understand',
#  680: 'authentic',
#  681: 'venture',
#  682: 'Eew',
#  683: 'wasted',
#  684: 'like',
#  685: 'fav',
#  686: 'leather',
#  687: 'spends',
#  688: 'haunt',
#  689: 'disbelief',
#  690: 'stomach',
#  691: 'cause',
#  692: 'finally',
#  693: 'airline',
#  694: 'gone',
#  695: 'greatest',
#  696: 'MANY',
#  697: 'Cod',
#  698: 'sick',
#  699: 'Waiter',
#  700: 'friends',
#  701: 'experience',
#  702: 'Cartel',
#  703: 'particular',
#  704: 'eyed',
#  705: 'mood',
#  706: 'apologize',
#  707: 'Café',
#  708: 'papers',
#  709: 'BLAND',
#  710: 'choose',
#  711: 'crowds',
#  712: 'thought',
#  713: 'GREAT',
#  714: 'nut',
#  715: 'give',
#  716: 'employees',
#  717: 'never',
#  718: 'once',
#  719: 'Im',
#  720: 'fries',
#  721: 'itself',
#  722: 'madhouse',
#  723: 'definitely',
#  724: 'appetizers',
#  725: 'OK',
#  726: '1979',
#  727: 'soggy',
#  728: 'And',
#  729: 'play',
#  730: 'spotty',
#  731: 'imagination',
#  732: 'Vegas',
#  733: 'loving',
#  734: 'were',
#  735: 'beans',
#  736: 'iced',
#  737: 'right',
#  738: 'accomodate',
#  739: 'pulled',
#  740: 'worker',
#  741: 'grossed',
#  742: 'watered',
#  743: 'ohhh',
#  744: 'Then',
#  745: 'handed',
#  746: 'but',
#  747: 'Frenchman',
#  748: 'hardly',
#  749: 'elsewhere',
#  750: 'worse',
#  751: 'soundtrack',
#  752: 'WILL',
#  753: 'Anyway',
#  754: 'Same',
#  755: 'tough',
#  756: 'ate',
#  757: 'beef',
#  758: 'Dog',
#  759: 'beer',
#  760: 'disappointment',
#  761: 'stretch',
#  762: 'styrofoam',
#  763: 'dinners',
#  764: 'decorated',
#  765: "'ve",
#  766: 'tender',
#  767: 'hand',
#  768: 'hungry',
#  769: 'Francisco',
#  770: 'Furthermore',
#  771: 'whatsoever',
#  772: 'dough',
#  773: 'set',
#  774: 'round',
#  775: 'spots',
#  776: 'thing',
#  777: '20',
#  778: 'AYCE',
#  779: 'hours',
#  780: 'Server',
#  781: 'old',
#  782: 'watched',
#  783: 'winner',
#  784: 'kind',
#  785: 'courteous',
#  786: 'tummy',
#  787: 'regularly',
#  788: 'some',
#  789: 'leftover',
#  790: 'bird',
#  791: 'actually',
#  792: 'Omelets',
#  793: 'memory',
#  794: 'part',
#  795: 'it',
#  796: 'Khao',
#  797: 'restaurants',
#  798: 'wonderful',
#  799: 'gratuity',
#  800: '90',
#  801: 'combination',
#  802: 'Pretty',
#  803: 'first',
#  804: 'bunch',
#  805: 'salty',
#  806: 'done',
#  807: 'cranberry',
#  808: '%',
#  809: 'Kind',
#  810: 'duo',
#  811: 'any',
#  812: 'ice',
#  813: 'businesses',
#  814: 'Stopped',
#  815: 'tried',
#  816: 'tea',
#  817: 'Awesome',
#  818: 'tasty',
#  819: 'summer',
#  820: 'sewer',
#  821: 'wedges',
#  822: 'boy',
#  823: 'working/eating',
#  824: 'guess',
#  825: 'others',
#  826: 'disgust',
#  827: 'WAY',
#  828: 'obviously',
#  829: 'die',
#  830: 'flop',
#  831: 'pricey',
#  832: 'bad',
#  833: 'equally',
#  834: 'Gringos',
#  835: 'number',
#  836: 'husband',
#  837: '6',
#  838: 'behind',
#  839: 'Sooooo',
#  840: 'stinks',
#  841: 'mind',
#  842: 'music',
#  843: 'ALL',
#  844: 'Otto',
#  845: 'silently',
#  846: 'exactly',
#  847: 'means',
#  848: '3',
#  849: 'tomato',
#  850: 'brought',
#  851: 'setting',
#  852: 'sad',
#  853: 'downside',
#  854: 'quit',
#  855: 'sub-par',
#  856: "'ll",
#  857: 'Sushi',
#  858: 'coffee',
#  859: 'between',
#  860: 'found',
#  861: 'We',
#  862: 'wings',
#  863: 'hardest',
#  864: 'promise',
#  865: 'Seafood',
#  866: 'late',
#  867: 'wo',
#  868: 'to-go',
#  869: 'Now',
#  870: 'mid',
#  871: 'containers',
#  872: 'shirt',
#  873: 'NYC',
#  874: 'establishment',
#  875: 'Avoid',
#  876: 'staff',
#  877: 'Our',
#  878: 'fish',
#  879: 'cover',
#  880: 'version',
#  881: 'everyone',
#  882: 'writing',
#  883: '.....',
#  884: 'milk',
#  885: 'entire',
#  886: 'profiterole',
#  887: 'shoe',
#  888: 'expensive',
#  889: 'in',
#  890: 'pizzas',
#  891: "'m",
#  892: 'MANAGEMENT',
#  893: 'water',
#  894: 'North',
#  895: 'loves',
#  896: 'correction',
#  897: 'tailored',
#  898: 'fact',
#  899: 'DELICIOUS',
#  900: 'buffets',
#  901: 'Also',
#  902: 'spring',
#  903: 'whether',
#  904: 'absolutley',
#  905: 'How',
#  906: 'When',
#  907: 'driving',
#  908: 'atmosphere',
#  909: 'Greek',
#  910: 'workers',
#  911: 'pita',
#  912: 'All',
#  913: 'instead',
#  914: 'Crust',
#  915: 'Bouchon',
#  916: 'myself',
#  917: 'beautifully',
#  918: 'drinking',
#  919: 'FREEZING',
#  920: 'cheese',
#  921: 'nude',
#  922: 'grow',
#  923: 'decor',
#  924: 'sever',
#  925: 'consider',
#  926: 'somewhat',
#  927: 'free',
#  928: 'Macarons',
#  929: 'more',
#  930: 'expect',
#  931: 'minutes',
#  932: 'finger',
#  933: 'Thumbs',
#  934: 'weekly',
#  935: 'probably',
#  936: 'effort',
#  937: 'fellow',
#  938: 'appalling',
#  939: 'Customer',
#  940: 'OMG',
#  941: 'sandwiches',
#  942: 'bartender',
#  943: 'Madison',
#  944: 'book',
#  945: 'horrible',
#  946: 'changing',
#  947: 'sunglasses',
#  948: 'pricing',
#  949: 'desserts',
#  950: 'somehow',
#  951: 'room',
#  952: 'venue',
#  953: 'recommend',
#  954: 'awkward',
#  955: 'Based',
#  956: 'recommendation',
#  957: 'Not',
#  958: 'flavors',
#  959: 'especially',
#  960: 'few',
#  961: 'little',
#  962: 'extraordinary',
#  963: 'will',
#  964: 'assure',
#  965: 'Crystals',
#  966: 'reservation',
#  967: 'showed',
#  968: 'ten',
#  969: 'LEGIT',
#  970: 'places',
#  971: 'crumby',
#  972: 'go',
#  973: 'drawing',
#  974: 'ESTABLISHMENT',
#  975: 'GO',
#  976: 'stale',
#  977: 'Mushroom',
#  978: 'whole',
#  979: 'ca',
#  980: 'refused',
#  981: 'original',
#  982: 'Area',
#  983: 'turn',
#  984: 'rating',
#  985: '10',
#  986: 'Good',
#  987: 'TV',
#  988: 'First',
#  989: 'sangria',
#  990: 'lovely',
#  991: 'fairly',
#  992: 'THAT',
#  993: 'he',
#  994: 'bus',
#  995: 'atrocious',
#  996: 'Salad',
#  997: 'market',
#  998: 'hands-down',
#  999: 'care',
#  ...}

# %% [markdown]
# ## 轉換句子為bag of words型式

# %%
def _get_bag_of_words_vector(sentence, word_index_dic, whole_words):
    sentence = sentence
    '''創建一個vector'''
    vector = np.zeros(len(word_index_dic))
    for word in nltk.word_tokenize(sentence):
        if word in whole_words:
            '''自行填入'''
            vector[word_index_dic[word]] += 1
    return vector

# %%
_get_bag_of_words_vector('Wow... Loved this place.', word_index, whole_words)
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])
